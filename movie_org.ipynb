# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
movie = pd.read_csv("/Users/jiwonkwun/Asac/Bechdel-IMDB-project/movies_org.csv", index_col=0, converters={'imdbid': lambda x: str(x)})

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9601 entries, 0 to 9600
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   imdbid            9601 non-null   object
#  1   title             9601 non-null   object
#  2   year              9601 non-null   object
#  3   imdb_rating       9569 non-null   float64
#  4   estimated budget  7151 non-null   object
#  5   world gross       7151 non-null   object
#  6   id                9601 non-null   float64
#  7   year_y            9601 non-null   float64
#  8   bechdel_rating    9601 non-null   float64
# dtypes: float64(4), object(5)
# memory usage: 750.1+ KB

# %%
movie.rename(columns={'world gross': 'world_gross', 'estimated budget':'estimated_budget'},inplace=True)

# %%
movie
# Out:
#         imdbid                              title  year  imdb_rating
# 0      3155794                   Passage de Venus  1874          6.8  \
# 1     14495706                  La Rosace Magique  1877          5.8
# 2      2221420         Sallie Gardner at a Gallop  1878          7.4
# 3     12592084                  Le singe musicien  1878          6.0
# 4      7816420            Athlete Swinging a Pick  1881          5.1
# ...        ...                                ...   ...          ...
# 9596  10954600  Ant-Man and the Wasp: Quantumania  2023          6.2
# 9597  12844910                            Pathaan  2023          6.0
# 9598  10365998                      Infinity Pool  2023          6.1
# 9599  14209916                       Cocaine Bear  2023          6.0
# 9600  25971180                 Les choses simples  2023          7.1
#
#               estimated_budget   world_gross       id  year_y  bechdel_rating
# ...

# %%
movie.drop(columns=['id','year_y'], inplace=True)

# %%
movie['estimated_budget'] = movie['estimated_budget'].fillna('')

# %%
movies = movie

# %%
movies['world_gross'] = movies['world_gross'].str.replace('$','')

# %%
movies['world_gross'] = movies['world_gross'].str.replace(',','')

# %%
movies.rename(columns={'world_gross': 'world_gross($)'}, inplace=True)

# %%
movies
# Out:
#         imdbid                              title  year  imdb_rating
# 0      3155794                   Passage de Venus  1874          6.8  \
# 1     14495706                  La Rosace Magique  1877          5.8
# 2      2221420         Sallie Gardner at a Gallop  1878          7.4
# 3     12592084                  Le singe musicien  1878          6.0
# 4      7816420            Athlete Swinging a Pick  1881          5.1
# ...        ...                                ...   ...          ...
# 9596  10954600  Ant-Man and the Wasp: Quantumania  2023          6.2
# 9597  12844910                            Pathaan  2023          6.0
# 9598  10365998                      Infinity Pool  2023          6.1
# 9599  14209916                       Cocaine Bear  2023          6.0
# 9600  25971180                 Les choses simples  2023          7.1
#
#               estimated_budget  world_gross($)  bechdel_rating
# 0                                            0             0.0
# ...

# %%
movies['world_gross($)'] = movies['world_gross($)'].fillna('')
# movies['world_gross($)'].fillna('').astype(int)

# %%
movies[movies['world_gross($)'].str.contains(' ')]
# Out:
# Empty DataFrame
# Columns: [imdbid, title, year, imdb_rating, estimated_budget, world_gross($), bechdel_rating]
# Index: []

# %%
movies.loc[5437,'world_gross($)'] = '82360'

# %%
movies['world_gross($)'] = movies['world_gross($)'].replace('','0')

# %%
movies['world_gross($)'] = movies['world_gross($)'].astype(int)

# %%
movies.to_csv('movies_org1.csv')
