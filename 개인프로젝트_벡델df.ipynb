# %%
import pandas as pd

# %%
df = pd.read_json('http://bechdeltest.com/api/v1/getAllMovies')

# %%
df.head()
# Out:
#                         title    id    imdbid  year  rating
# 0            Passage de Venus  9602   3155794  1874       0
# 1           La Rosace Magique  9804  14495706  1877       0
# 2  Sallie Gardner at a Gallop  9603   2221420  1878       0
# 3           Le singe musicien  9806  12592084  1878       0
# 4     Athlete Swinging a Pick  9816   7816420  1881       0

# %%
df.tail()
# Out:
#                    title     id    imdbid  year  rating
# 9903             Pathaan  10728  12844910  2023       3
# 9904             Missing  10754  10855768  2023       3
# 9905       Infinity Pool  10737  10365998  2023       2
# 9906        Cocaine Bear  10779  14209916  2023       3
# 9907  Les choses simples  10785  25971180  2023       1

# %%
df.to_csv('bechdel.csv')

# %% [markdown]
# IMDB

# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import numpy as np
import re
import pandas as pd
import time

# %%
url = "https://www.imdb.com/search/title/?groups=top_1000"
# url = "https://www.imdb.com/search/title/?groups=top_1000&start=51&ref_=adv_nxt"

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36"}
res = requests.get(url,headers=headers)
soup = BeautifulSoup(res.text, "html.parser")

# %%
pages = np.arange(1,1001,50)
pages
# Out:
# array([  1,  51, 101, 151, 201, 251, 301, 351, 401, 451, 501, 551, 601,
#        651, 701, 751, 801, 851, 901, 951])

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
print(soup.prettify())

# %% [markdown]
# https://developer-ankiwoong.tistory.com/843
# https://www.imdb.com/search/title/?groups=top_1000&sort=user_rating,desc

# %%
# 데이터 변수 리스트 생성
titles = []
years = []
imdb_ratings =[]
metascores = []
votes = []
us_gross = []

# %%
movie_div = soup.find_all('div', class_ = 'lister-item mode-advanced')

# %%
# titles
for con in movie_div:
  name = con.h3.a.text
  titles.append(name)

# %%
titles

# %%
# years
for con in movie_div:
  year = con.h3.find('span', class_ = 'lister-item-year').text
  years.append(year)

# %%
years

# %%
# imdb rating
for con in movie_div:
  imdb = float(con.find('strong').text)
  imdb_ratings.append(imdb)

# %%
# meta score
for con in movie_div:
  meta = con.find('span', class_='metascore').text
  if len(meta) > 1:
    metascores.append(meta.strip())
  else: metascores.append(np.nan)

# %%
#https://truman.tistory.com/107
#votes = []
for con in movie_div:
  vote = con.find('span', attrs={'name':"nv"}).text#['data-value'] # attrs: 속성 값 모두 출력
  # vote = con.find_all('span', attrs={'name':"nv"})[0].text # attrs: 속성 값 모두 출력

  print(vote)
  # if len(vote)>1:
    # votes.append(int(vote))
  # else:
    # votes.append(np.nan)
# Out:
# 136,895
# 369,115
# 436,573
# 577,010
# 135,431
# 1,900,959
# 123,087
# 202,163
# 2,733,815
# 1,897,432
# 666,916
# 694,455
# 2,100,755
# 1,202,460
# 806,030
# 599,190
# 2,706,930
# 1,454,847
# 2,402,818
# 1,215,412
# 723,524
# 171,415
# 773,287
# 789,199
# 651,365
# 1,171,323
# 419,281
# 199,486
# 358,114
# 900,025
# 2,176,520
# 898,156
# 1,338,631
# 1,909,395
# 998,780
# 59,577
# 1,530,121
# 1,010,133
# 786,019
# 470,792
# 846,902
# 1,232,991
# 1,461,862
# 1,485,196
# 741,180
# 1,343,971
# 636,703
# 1,690,115
# 859,199
# 834,262

# %%
votes

# %%
# us_gross = []
for con in movie_div:
  gross = con.find('span', attrs={'name':'nv'}).findNext('span', attrs={'name':'nv'})['data-value'].replace(',','')
  if len(gross) > 3:
    us_gross.append(int(gross))
  else: us_gross.append(np.nan)

# %%
us_gross

# %%
df = pd.DataFrame({
    'movie' : titles,
    'year' : years,
    'imdb' : imdb_ratings,
    'metascore': metascores,
    'votes' : votes,
    'us_gross_dollars': us_gross 
})

# %%
df.head()
# Out:
#                                movie    year  imdb metascore   votes  \
# 0               John Wick: Chapter 4  (2023)   8.2        78  136895
# 1           Avatar: The Way of Water  (2022)   7.7        67  369115
# 2  Everything Everywhere All at Once  (2022)   7.9        81  436573
# 3                  Top Gun: Maverick  (2022)   8.3        78  577010
# 4                          The Whale  (2022)   7.7        60  135431
#
#    us_gross_dollars
# 0               NaN
# 1       659682302.0
# 2        72861480.0
# 3       718732821.0
# 4         1900959.0

# %%
df.dtypes
# Out:
# movie                object
# year                 object
# imdb                float64
# metascore            object
# votes                 int64
# us_gross_dollars    float64
# dtype: object

# %% [markdown]
# #전처리 과정

# %%
df['year'] = df['year'].str.extract('(\d+)').astype(int)
print(df['year'])

# %%
df['metascore'] = df['metascore'].astype(int)
print(df['metascore'])

# %%
df
# Out:
#                                                 movie  year  imdb  metascore  \
# 0                                John Wick: Chapter 4  2023   8.2         78
# 1                            Avatar: The Way of Water  2022   7.7         67
# 2                   Everything Everywhere All at Once  2022   7.9         81
# 3                                   Top Gun: Maverick  2022   8.3         78
# 4                                           The Whale  2022   7.7         60
# 5                                       The Godfather  1972   9.2        100
# 6                        Puss in Boots: The Last Wish  2022   7.9         73
# 7                           The Banshees of Inisherin  2022   7.7         87
# 8                            The Shawshank Redemption  1994   9.3         82
# 9                                        Interstellar  2014   8.6         74
# 10                                               Dune  2021   8.0         74
# 11                                         The Batman  2022   7.8         72
# 12                                       Pulp Fiction  1994   8.9         95
# 13                            Guardians of the Galaxy  2014   8.0         76
# 14              Harry Potter and the Sorcerer's Stone  2001   7.6         65
# 15                                  Blade Runner 2049  2017   8.0         81
# 16                                    The Dark Knight  2008   9.0         84
# 17                            The Wolf of Wall Street  2013   8.2         75
# 18                                          Inception  2010   8.8         74
# 19                                            Titanic  1997   7.9         75
# 20                                         Knives Out  2019   7.9         82
# 21                                       Evil Dead II  1987   7.7         72
# 22                      Once Upon a Time in Hollywood  2019   7.6         83
# 23                            Spider-Man: No Way Home  2021   8.2         71
# 24                                    American Psycho  2000   7.6         64
# 25                                  Avengers: Endgame  2019   8.4         78
# 26                                       The Exorcist  1973   8.1         81
# 27                     All Quiet on the Western Front  2022   7.8         76
# 28                                      The Gentlemen  2019   7.8         51
# 29                                              Alien  1979   8.5         89
# 30                                         Fight Club  1999   8.8         66
# 31                                           Whiplash  2014   8.5         89
# 32                                             Avatar  2009   7.9         83
# 33  The Lord of the Rings: The Fellowship of the Ring  2001   8.8         92
# 34                                  Good Will Hunting  1997   8.3         70
# 35                                           Aftersun  2022   7.7         95
# 36                                          Gladiator  2000   8.5         67
# 37                                      Jurassic Park  1993   8.2         68
# 38                                         Black Swan  2010   8.0         79
# 39                                           The Help  2011   8.1         62
# 40                                           Parasite  2019   8.5         96
# 41                                 Back to the Future  1985   8.5         87
# 42                           The Silence of the Lambs  1991   8.6         86
# 43                               Inglourious Basterds  2009   8.3         69
# 44                                          Prisoners  2013   8.1         70
# 45                                              Joker  2019   8.4         59
# 46                                            Get Out  2017   7.7         85
# 47                                              Se7en  1995   8.6         65
# 48                                        Taxi Driver  1976   8.2         94
# 49                           The Grand Budapest Hotel  2014   8.1         88
#
#       votes  us_gross_dollars
# 0    136895               NaN
# 1    369115       659682302.0
# 2    436573        72861480.0
# 3    577010       718732821.0
# 4    135431         1900959.0
# 5   1900959       134966411.0
# 6    123087       168464485.0
# 7    202163         2733815.0
# 8   2733815        28341469.0
# 9   1897432       188020017.0
# 10   666916       108327830.0
# 11   694455       369345583.0
# 12  2100755       107928762.0
# 13  1202460       333176600.0
# 14   806030       317575550.0
# 15   599190        92054159.0
# 16  2706930       534858444.0
# 17  1454847       116900694.0
# 18  2402818       292576195.0
# 19  1215412       659325379.0
# 20   723524       165359751.0
# 21   171415         5923044.0
# 22   773287       142502728.0
# 23   789199       804747988.0
# 24   651365        15070285.0
# 25  1171323       858373000.0
# 26   419281       232906145.0
# 27   199486          358114.0
# 28   358114        36471795.0
# 29   900025        78900000.0
# 30  2176520        37030102.0
# 31   898156        13092000.0
# 32  1338631       760507625.0
# 33  1909395       315544750.0
# 34   998780       138433435.0
# 35    59577         1530121.0
# 36  1530121       187705427.0
# 37  1010133       402453882.0
# 38   786019       106954678.0
# 39   470792       169708112.0
# 40   846902        53367844.0
# 41  1232991       210609762.0
# 42  1461862       130742922.0
# 43  1485196       120540719.0
# 44   741180        61002302.0
# 45  1343971       335451311.0
# 46   636703       176040665.0
# 47  1690115       100125643.0
# 48   859199        28262574.0
# 49   834262        59100318.0
